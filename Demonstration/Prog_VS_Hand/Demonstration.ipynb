# %% [markdown]
# # Extracting Instruction
#
# It demonstrates a workability of our approach to extract action-instructions from text. For each test document there is a set of names of extracted action and for each action there is a sentence involving the action.
#
# All documents was taken from [this google-disk](https://drive.google.com/drive/folders/1JUv5yHlHYR6hHf3d6MhVKiFjo5Zc4hEN). There are original documents names and links to them below.

# %%
import sys
sys.path.append('../../')
from ScriptExtract.Preprocessing.TextProcessing import text_separation
#from TextProcessing import research_list, show

# %% [markdown]
# ## 1. File 'Инструкция по покупке подержанного авто для «продвинутого чайника».txt'
#
# The original is [Инструкция по покупке подержанного авто для «продвинутого чайника»](https://docs.google.com/document/d/1AkoVHz2eJh4xmADGxkzjmS4slSN-Lbpd8xPwfjLBcrE/edit).

# %% [markdown]
# ### 1.1. Programm Result

# %%
handle = open("Инструкция по покупке подержанного авто для «продвинутого чайника».txt", "r")
text = handle.read()
handle.close()

list_ = text_separation(text).get_list_of_tree()

# %%
import sys
sys.path.append('../../')
from ScriptExtract.Preprocessing.TextProcessing import table

# %%
handle = open("Инструкция по покупке подержанного авто для «продвинутого чайника».txt", "r")
text = handle.read()
handle.close()
a = table().extract_one(text)

# %%
k = 0
for i in a[0]:
    if i['IsInstr']:
        k += 1
        print("%d. "%(k)+i['Sentence'])
# Out:
# 1. Если Вы твердо решили купить подержанный автомобиль, но в авто особо не разбираетесь – попробуйте следовать нижеприведенным инструкциям.
# 2.  С их помощью Вы сможете увеличить свои шансы купить авто, которое действительно стоит тех денег, которые Вы за него готовы отдать.
# 3.  Точно определитесь с суммой, которую Вы готовы потратить на приобретение автомобиля.
# 4.  Вычтите из нее 10% - оставшиеся 90% будут той максимальной ценой, по которой Вы сможете купить авто.
# 5.  Морально настройтесь на длительные поиски.
# 6.  Определитесь (хотя бы примерно) с маркой и моделью автомобиля, который хотите приобрести.
# 7.  Соберите информацию, почитайте форумы, запишите все слабые места, на которые стоит обратить внимание при осмотре машины.
# 8.  Если есть возможность, обязательно возьмите с собой на осмотр напарника, желательно разбирающегося в авто.
# 9.  Прежде чем договариваться с владельцем о встрече для осмотра автомобиля, полезно будет задать несколько вопросов по телефону.
# ...

# %%
from TextProcessing import get_file
get_file(list_, "Инструкция по покупке подержанного авто для «продвинутого чайника».md")

# %% [markdown]
# ### 1.2. Script made by hand
#
# 1. Подготовка:
#    1. Определиться с суммой **+**
#    2. Длительный поиск **+**
#    3. Определиться с маркой и моделью **+**
#    4. Взять на осмотр напарника **+**
# 1. Созвон с владельцем
#    1. Задать все вопросы из списка автора **+**
#    2. Договориться о встрече **-**
# 1. Встреча и осмотр автомобиля
#    1. Взять с собой предметы из списка автора **+**
#    2. Осмотр кузова:
#       1. попросить владельца вымыть авто **+**
#       2. осмотреть борта, капот и крышу **+**
#       3. осмотр багажника **+**
#       4. осмотр стыков **+**
#       5. дефекты под наклейками **+**
#       6. проверка кузовной геометрии **-+**
#       7. сравнить цвет краски **+**
#       8. крепления бампера и лонжероны **+**
#       9. коррозия **+**
#    1. Завести автомобиль
#       1. проверка лампочек на приборной панели (в зажиганием и запущенным двигателем):
#          1. масло **+**
#          2. ручник **+**
#          3. подушки безопасности **+**
#    1. Проверка подвески, тормоза и ходовой части
#       1. проверить люфты на руле и колесах **+**
#       2. проверить чехлы шарниров подвески и рулевого управления, шарниров полуосей **+**
#       3. поискать вмятины и трещины на дисках **+**
#       4. сравнить износ покрышек **+**
#       5. проверить амортизаторы, резиновые отбойники, пыльники амортизаторов **+**
#       6. проверить тормозные шланги **+**
#       7. осмотреть пыльники направляющих суппортов **+**
#       8. осмотреть пыльники цилиндров **+**
#       9. сравнить толщину накладок тормозных колодок **+**
#    1. Проверка салона
#       1. проверить цельность обивки, панелей и чехлов **+**
#       2. проверить прочность креплений обивки крыши и дверей **+**
#       3. проверить регулировки сидений **+**
#       4. осмотреть руль **+**
#       5. проверить световые приборы **+**
#       6. проверить работу дворников и омывателей **+**
#       7. проверить стеклоподъемники **+**
#       8. проверить все дополнительные опции **+**
#       9. проверить пространство под ковриками **+**
#    1. Осмотр выключенного двигателя
#       1. осмотреть двигателя **+**
#       2. осмотреть горловину для залива масла **+**
#       3. осмотреть систему охлаждения **+**
#    1. Осмотр работающего двигателя
#    2. ….

# %% [markdown]
# ## 2. File 'Инструкиция с Drom.ru.txt'
#
# The original is [Инструкиция с Drom.ru](https://docs.google.com/document/d/1YDqcdjQb1rpiMO9ExeYpqG4-bOfWF1GDXv4c9BdcGvA/edit#heading=h.yhvkvjvt9bpg).

# %% [markdown]
# ### 2.1. Programm Result

# %%
import sys
sys.path.append('../..')

from TextProcessing import graph_construct as GC
from TextProcessing import research_list, show
handle = open("Инструкиция с Drom.ru.txt", "r")
text = handle.read()
handle.close()

list_ = GC(text).get_list()

# %%
show(list_)
# Out:
# Section ﻿Как безопасно купить или продать автомобиль по объявлению
#
#
#
# Section Покупателю автомобиля
#
#
#
# Section Покупка машины по объявлению состоит из трёх основных шагов
#
#
# Section list  Поиск интересующего авто по объявлениям: на что обратить внимание, какие подвохи бывают.
#
# Section list  Разговор с продавцом, осмотр автомобиля и документов к нему: какие здесь есть тонкости.
#
# Section list  Оформление автомобиля на своё имя: договор купли-продажи, регистрационные действия и как с ними не пролететь.
#
# Section list  Как грамотно разместить объявление о продаже своей машины.
# Action Action2{размещать}
# Sentence Как грамотно разместить объявление о продаже своей машины .
#
# Section list  Какие документы надо подготовить для продажи, как их оформить.
# Action Action3{подготовить}
# Sentence Какие документы надо подготовить для продажи , как их оформить .
#
# Section list  Какие схемы развода бывают в случае продажи авто.
# Action Action9{отсекать}
# ...

# %%
get_file(list_, "Инструкиция с Drom.ru.md")

# %% [markdown]
# ### 2.2. Script made by hand
#
# Сценарий покупателя:
# 1. Поиск интересующего авто по объявлениям. О чем важно помнить:
#    1. не оставлять задатки продавцу +
#    2. оценить среднюю рыночную стоимость автомобиля +
#    3. проверить документы (если машина на иностранных номерах - придется потратиться на растаможку) +
#    4. если машина на номерах другого региона +
#       1. поискать объявления с этими же фотографиями но другими параметрами или владельцами
#       2. задавать вопросы продавцу и анализировать ответы
#    1. не рассматривать объявление без фото или с плохими фотографиями -
#    2. не рассматривать автомобили без документов (даже на запчатси) -
#    3. проверить, что нет запрета на регистрационные действия -
#    4. проверить, что машина не в залоге/кредите/лизинге +
#    5. пробить машину по базе ГИБДД (по VIN и госномеру) +
#    6. проверить количество владельцев -
# 1. Разговор с продавцом
#    1. проверить, является ли продавец собственником +
#    2. проверить паспорт владельца на сайте ФМС +
#    3. переспросить год выпуска и пробег автомобиля +
#    4. узнать, в каком регионе эксплуатировалась машина, проверить штрафы -
#    5. узнать, что идет в комплекте с машиной +
#    6. попросить у владельца фото/скан ПТС, СТС, номерных знаков, или попросить продиктовать номер машины, СТС, VIN, ФИО и дату рожденя владельца -
# 1. Личная встреча с продавцом
#    1. проверить документы: +
#       1. ПТС
#          1. все номера и данные автомобиля из ПТС совпадают с тем, что указано в объявлении +
#          2. посмотреть раздел “Особые отметки” +
#          3. посмотреть раздел “Таможенные ограничения” +
#          4. проверить отметку “Дубликат” +
#          5. ПТС выдан в Бурятии или Чечне +
#       1. СТС +
#       2. Страховка +
#    1. сверить данные из документов с данными на автомобиле
#       1. проверить, что на номерах кузова/двигателя/шасси нет следов попытки изменить номер или отдельные символы в нем +
#    1. внешний осмотр
#       1. поискать следы ремонта: +
#          1. разное расстояние между деталями +
#          2. детали отличаются по цвету +
#          3. отличаются сварные точки в разных проемах +
#          4. качество сварных швов разное +
#          5. на креплениях есть следы воздействия +
#          6. новая краска на старой машине +
#          7. коррозия под сидениями/обшивкой +
#       1. осмотр салона
#          1. оценить возраст по состоянию салона +
#          2. проверить работу всех деталей (свет, регулировка сидений, подогрев…) +
# 1. Оформление автомобиля на нового владельца
#    1. составление ДКП:
#       1. ДКП составить в трех экземплярах -
#       2. не оформлять по генеральной доверенности +
#       3. в ДКП и ПТС расписывается только собственник или его законный представитель +
#       4. указать в ДКП реальную стоимость авто +
#       5. подробно расписать все параметры автомобиля в ДКП (пробег, состояние, ограничения) +
#       6. составить акт приема-передачи автомобиля +
#       7. оформить расписку о получении денег -
#    1. пройти проверку в ГИБДД -
#       1. проверка автомобиля сотрудниками ГИБДД +
#       2. составление заявления на оформление автомобиля +
#       3. предоставить ПТС, паспорт и договор купли-продажи +
#       4. получить СТС на свое имя +

# %% [markdown]
# ## 3. Results Of Comparison
#
# *The first document:* **97.4 %** of information from the script made by hand was found.
#
# *The second document:* **83.7 %** of information from the script made by hand was found.
