# %% [markdown]
# # Extracting Instruction
#
# It demonstrates a workability of our approach to extract action-instructions from text. For each test document there is a set of names of extracted action and for each action there is a sentence involving the action.
#
# All documents was taken from [this google-disk](https://drive.google.com/drive/folders/1JUv5yHlHYR6hHf3d6MhVKiFjo5Zc4hEN). There are original documents names and links to them below.

# %% [markdown]
# ## 1. File 'Инструкция по покупке подержанного авто для «продвинутого чайника».txt'
#
# The original is [Инструкция по покупке подержанного авто для «продвинутого чайника»](https://docs.google.com/document/d/1AkoVHz2eJh4xmADGxkzjmS4slSN-Lbpd8xPwfjLBcrE/edit).

# %% [markdown]
# ### 1.1. Programm Result

# %%
import sys
sys.path.append('../../')
from ScriptExtract.Preprocessing.TextProcessing import table

# %%
handle = open("../../Texts/text2_2.txt", "r")
text = handle.read()
print(len(text))
handle.close()
a = table().extract_one_new(text)
a[1]
# Out:
# 5996
# 41.31170034408569

# %%
k = 0
print(len(a))
print(a[0][0].keys())
for i in a[0]:
    if i['FirstLevel']:
        k += 1
        print("%d. "%(k)+i['Sentence'])
# Out:
# 2
# dict_keys(['Sentence', 'TagUd', 'SecondLevel', 'FirstLevel', 'Relations'])
# 1.   В данной статье я попытаюсь предоставить вам примерный алгоритм действий, которые необходимо будет провести при этом мероприятии, а так же попытаюсь донести кое-какие основы "этикета покупателя", если вообще таковой имеется, дабы не довести продавца "до ручки" глупыми вопросами и действиями=) Итак, после того как вы определились, какую марку и модель вы хотите приобрести, начинаем поиск.
# 2.   Отмечу, что машину стоит искать на авторитетных сайтах таких как: САЙТ САЙТ САЙТ и прочие.
# 3.   Далее так же стоит поинтересоваться, тот ли год выпуска в ПТС, что и указан в объявлении (зачастую на сайте, недобросовестные продавцы любят «приклеивать» год выпуска, мотивируя тем, что авто выпущено в 2007-м, а продано салоном в 2008-м).
# 4.   Стоит так же спросить про обслуживание транспортного средства: имеется ли сервисная книжка, отметки в ней, может быть сохранились чеки, заказ-наряды со станции тех.
# 5.   Так же стоит задать вопрос, готов ли продавец после первичного осмотра съездить на СТО и провести там диагностику.
# 6.   Ещё необходимо проверить данное транспортное средство на предмет залога.
# 7.   Договариваясь о встрече, не стоит приглашать продавца к себе, не ленитесь и приезжайте смотреть автомобиль сами.
# 8.   Не стоит соглашаться на предложенную станцию самим продавцом.
# 9.   Такую диагностику можно, например, оспорить в суде.
# 10.   Надо понимать, что вы на официальном дилере, тут что называется и запчасти подороже, так как оригинальные и стоимость работ повыше.
# 11.   Если вам насчитали ремонта на 50 тысяч рублей, поверьте не многие подвинуться.
# 12.   Но тянуть с этим не стоит, лучше всего сразу после заключения договора, поехать и поставить автомобиль на себя.
# 13.   Для собственного спокойствия и для спокойствия продавца, вы можете пригласить его с собой на регистрацию, дабы быть уверенным на все 100% что ТС не имеет ни каких юридических проблем, а продавец будет уверен, что ему больше не придут штрафы с камер видеонаблюдения, дорожный налог и прочие расходы.
# 14.   Да и не забудьте про полис ОСАГО, без него автомобиль вам не зарегистрируют.

# %%
k = 0
print(len(a))
print(a[0][0].keys())
for i in a[0]:
    if i['SecondLevel']:
        k += 1
        print("%d. "%(k)+i['Sentence'])
# Out:
# 2
# dict_keys(['Sentence', 'TagUd', 'SecondLevel', 'FirstLevel', 'Relations'])
# 1.   Сделать это можно на сайте САЙТ в разделе "Найти в реестре/по информации о предмете залога".
# 2.   Сделать это можно на сайте судебных приставов САЙТ.
# 3.   Сразу хочу заметить, что автомобиль нужно осматривать исключительно в дневное время и только после мойки.
# 4.  Договор купли-продажи можно выписать практически у любого МРЭО, а так же в организациях, которые занимаются переоформлением автомобилей, на различных площадках по продаже авто и прочее.

# %%
handle = open("../../Texts/text2_8.txt", "r")
text = handle.read()
print(len(text))
handle.close()
a = table().extract_one_new(text)
a[1]
# Out:
# 14596
# 91.7812271118164

# %%
k = 0
print(len(a))
print(a[0][0].keys())
for i in a[0]:
    if i['FirstLevel']:
        k += 1
        print("%d. "%(k)+i['Sentence'])
# Out:
# 2
# dict_keys(['Sentence', 'TagUd', 'SecondLevel', 'FirstLevel', 'Relations'])
# 1.   Оставьте 15% от этой суммы на ремонт, обслуживание и прочие расходы.
# 2.   Не надо думать, что вы найдёте автомобиль, в который не придётся вкладывать деньги.
# 3.   Оставляйте 15% и спите спокойно.
# 4.   Выбирайте только те автомобили, которые вы потянете по обслуживанию.
# 5.   Ограничьте себя годом выпуска и пробегом, с которым вы сможете жить.
# 6.   Только не занижайте желаемый пробег.
# 7.   Перед тем как искать машину, приготовьте всю сумму за неё наличными.
# 8.   Подпишитесь на обновления интересующих вас моделей в приложениях бесплатных объявлений и звоните сразу, как только человек выложил объявление.
# 9.   Самые хорошие машины по выгодным ценам покупают буквально за несколько часов, максимум — дней, так что не тормозите, не откладывайте звонок и встречу до вечера или до выходных.
# 10.   Никогда не ведитесь на объявления с явно заниженной ценой.
# 11.   Не тратьте время на объявления, у которых очень много просмотров: они фейковые.
# 12.   Не обращайте внимания на объявления с очень скудным описанием или несколькими фотографиями.
# 13.   Ищите в первую очередь частные объявления.
# 14.   «Серые» автосалоны часто проводят махинации с договорами, так что перечитывайте каждый лист, когда вам приносят документ на подписание.
# 15.   Покупать машину у перекупщика можно только в самом крайнем случае, если других вариантов нет и не предвидится.
# 16.   Машину с чистым двигателем и подкапотным пространством следует проверять с двойным пристрастием.
# 17.   Присматривайтесь к мелочам.
# 18.   Всегда задавайте по телефону максимально много вопросов.
# 19.   Спрашивайте не общие вещи, а конкретные.
# 20.   Запоминайте или даже записывайте ответы.
# 21.   В крайнем случае машину жены может продавать муж.
# 22.   Тогда проверьте штамп в паспорте.
# 23.   Проверяйте VIN на машине и в ПТС.
# 24.   Если можете, то возьмите в аренду толщиномер и посмотрите в интернете нормы толщины ЛКП для конкретной модели.
# 25.   Проверяйте толщину краски минимум в пяти местах на каждой детали.
# 26.   То есть дверь нужно измерять минимум в центре и в четырёх углах.
# 27.   Проверяйте толщину краски на крыше и в дверных проёмах, на стойках дверей.
# 28.   Если можете, возьмите в аренду прибор для диагностики электроники.
# 29.   Если не можете, не расстраивайтесь: с ним ещё нужно разбираться.
# 30.   Не покупайте машину с толщиной ЛКП больше 1 000 микрон на кузове и больше 400 микрон на силовых элементах кузова (стойках, лонжеронах и так далее).
# 31.   Сравнивайте оттенки и тона краски на соседних элементах кузова.
# 32.   Проверьте, нет ли в лаке вкраплений пыли и волос.
# 33.   Отогните уплотнитель, посмотрите, не отличается ли там тон краски.
# 34.   Проверьте маркировку и дату выпуска каждого стекла.
# 35.   Загляните под коврик в багажнике.
# 36.   В нише запасного колеса не должно быть воды и плесени.
# 37.   На них не должно быть складок, следов краски, мастики и чего-то ещё.
# 38.   Проверьте, одинаковые ли болты везде.
# 39.   Если есть, проверьте, есть ли аналогичные следы на самой двери.
# 40.   Проверьте амортизаторы, нажав на машину с каждого угла, чтобы она раскачалась.
# 41.   Если руль в чехле, снимите его, чтобы оценить реальное состояние.
# 42.   Принюхайтесь.
# 43.   В салоне не должно пахнуть сыростью или плесенью.
# 44.  Не должно быть вообще никаких посторонних запахов.
# 45.   Проверьте обивку под сиденьем.
# 46.   Она должна быть сухая и не должна рассыпаться.
# 47.   Поднимите коврики в салоне.
# 48.   На ковролине и под сиденьями не должно быть разводов.
# 49.   Проверьте, работают ли фиксаторы дверей.
# 50.   На передней панели не должно быть разрывов.
# 51.   Проверьте работу кондиционера.
# 52.   Проверьте, горят ли все контрольные лампы на панели приборов при включении зажигания.
# 53.   Проверьте масло.
# 54.   Масло не должно пахнуть гарью, не должно быть никаких посторонних частичек, налёта, мусора.
# 55.   Заведите машину.
# 56.   Из выхлопной трубы не должен идти густой дым любого цвета.
# 57.   Если машина на механике, проверьте сцепление.
# 58.   На автомате не должно быть рывков и дёрганий при переключении коробки из P в R или из R в D и обратно.
# 59.   Не должно быть рывков при переключениях во время движения с нажатой до упора педалью газа.
# 60.   Машину не должно уводить в сторону при движении.
# 61.   Выключите музыку и прислушайтесь к звукам.
# 62.   Любой звук зафиксируйте в голове, чтобы потом описать его профессионалу.
# 63.   Руль не должно бить, заодно, возможно, получится проверить работу ABS.
# 64.   Обо всех посторонних звуках, которые услышали во время тест-драйва, расскажите мастеру при заезде на сервис перед покупкой.
# 65.   Вам должны проверить подвеску и сказать, насколько всё там серьёзно.
# 66.   Если не делали диагностику электроники сами, проверьте её в ближайшем автосервисе.
# 67.   Торгуйтесь только обоснованно.
# 68.   Проверьте машину на сайте ГИБДД.
# 69.   Проверьте машину на сайте Федеральной службы судебных приставов.
# 70.   Проверьте машину на сайте САЙТ если покупаете машину в Москве и области.
# 71.   Проверьте машину по базе Федеральной нотариальной палаты.
# 72.   Составлять договор купли-продажи можно в простой письменной форме одной ручкой и одним почерком.
# 73.   Указывайте дату и время сделки в договоре купли-продажи.
# 74.   Чётко прописывайте стоимость автомобиля и сумму, переданную продавцу.
# 75.   Прописывайте пункт о том, что автомобиль на момент составления договора не был продан кому-то ещё, на него не имеет права собственности кто-то ещё, автомобиль не заложен, не арестован и не является предметом спора.
# 76.   Вносить изменения в ПТС нужно только одной ручкой и одним почерком.
# 77.   Если вы отдали деньги продавцу, а он вдруг просит вас расторгнуть договор и возвращает деньги, проверяйте деньги в банке.
# 78.   Перерегистрировать машину на себя нужно в течение десяти дней, иначе будут проблемы.
# 79.   Проверяйте, чтобы в ДКП, ПТС и паспорте был один и тот же человек.
# 80.   Не ставьте свою подпись в ПТС, где уже стоит подпись прежнего владельца.
# 81.   Верьте только тому, что проверили сами, не доверяйте продавцам.
# 82.   Не покупайте машину у друга, родственника, знакомого без проверки.
# 83.   Дайте ему хотя бы эти правила или проверяйте параллельно сами.

# %%
k = 0
print(len(a))
print(a[0][0].keys())
for i in a[0]:
    if i['SecondLevel']:
        k += 1
        print("%d. "%(k)+i['Sentence'])
# Out:
# 2
# dict_keys(['Sentence', 'TagUd', 'SecondLevel', 'FirstLevel', 'Relations'])
# 1.   Определите список опций, которые точно должны быть.
# 2.   Продавать машину должен тот, кто указан в качестве владельца в ПТС.
# 3.   Он не должен выступать за кузов.
# 4.   Подкапотное пространство не должно быть вымытым, но и не должно быть подтёков — только следы нормальной эксплуатации.
# 5.   Лампочки давления масла и подушек безопасности должны гаснуть по отдельность.
# 6.   Уровень должен быть между отметками «минимум» и «максимум».
# 7.   Масло не должно пахнуть гарью, не должно быть никаких посторонних частичек, налёта, мусора.
# 8.   Руль не должно бить, заодно, возможно, получится проверить работу ABS.
# 9.   Вместе с ПТС и ДКП продавец должен вам передать два комплекта ключей, в том числе от сигнализации и противоугонки, СТС, диагностическую карту.
# 10.   Загонять в сервис для проверки нужно только автомобиль, который устраивает по всем остальным параметрам.

# %%
handle = open("../../Texts/text2_10.txt", "r")
text = handle.read()
print(len(text))
handle.close()
a = table().extract_one_new(text)
a[1]
# Out:
# 21945
# 164.30705332756042

# %%
k = 0
print(len(a))
print(a[0][0].keys())
for i in a[0]:
    if i['FirstLevel']:
        k += 1
        print("%d. "%(k)+i['Sentence'])
# Out:
# 2
# dict_keys(['Sentence', 'TagUd', 'SecondLevel', 'FirstLevel', 'Relations'])
# 1.   САЙТ подготовил для вас разбор подводных камней выбора и приобретения авто, который поможет вам сориентироваться в нюансах купли-продажи автомобилей.
# 2.   Как грамотно разместить объявление о продаже своей машины.
# 3.   Какие документы надо подготовить для продажи, как их оформить.
# 4.  Задатки и предоплаты Никогда не оставляйте задатков продавцу!
# 5.   Есть популярная схема обмана: продавец может попросить вас оставить ему задаток или предоплату.
# 6.  Поэтому при выборе авто руководствуйтесь средней ценой на такие машины в вашем регионе.
# 7.   Для этого на САЙТ есть сервис «Оценить моё авто», где можно быстро выяснить среднюю стоимость любой машины.
# 8.   В описании к такому объявлению может быть указано, что есть пакет документов «на передвижение».
# 9.  Машина в залоге, кредите, лизинге Если в объявлении указано, что машина в залоге, или вы это выяснили в процессе общения с продавцом, то разрешение на смену владельца авто нужно спрашивать у залогодержателя (банка, ломбарда и САЙТ или у фактического собственника (лизинг), а не у человека, который разместил объявление, поскольку ему машина не принадлежит.
# 10.   Обязательно проверьте, не числится ли автомобиль в реестре залогов по движимому имуществу.
# 11.  Сколько владельцев сменил автомобиль В объявлениях на САЙТ можно увидеть количество владельцев автомобиля (периоды регистрации в ГИБДД).
# 12.   В процессе общения по телефону или через сайт можно выяснить дополнительные подробности про интересующий вас автомобиль.
# 13.   На этом шаге важно обратить внимание на следующие моменты.
# 14.   Если документ окажется не действителен, то от сделки с таким собственником лучше отказаться.
# 15.   Выяснить это можно будет только при попытке поставить машину на учет.
# 16.  Узнайте, идет ли что-нибудь в комплекте с машиной (второй комплект колес, какие-то купленные, но не установленные запчасти) Нормальный владелец обычно отвечает внятно и подробно.
# 17.   Поскольку большая часть конструкторов в настоящее время является нелегальной, над покупкой такого варианта стоит как следует задуматься.
# 18.   Следует насторожиться.
# 19.   В нем в графе «Таможенные ограничения» должна стоять отметка «Не установлены», что означает легальное оформление и выплату всех пошлин.
# 20.  СТС (СОР) Обязательно сверяйте данные ПТС с тем, что написано в СТС.
# 21.   Будьте внимательны.
# 22.  После знакомства с документами первым делом сверьте их с реальным автомобилем Пристально нужно осмотреть маркировку идентификационных номеров, и лучше заранее узнать, где на этой модели ее искать.
# 23.  Чего не должно быть на VIN, номере кузова, двигателя, шасси: нечитаемых символов, отличающихся от остальных символов, отличия крепления, швов рядом с табличками, посторонних примесей и отличий по тону под краской или лаком.
# 24.  При самостоятельном осмотре машины следует обратить внимание на следующие пункты, указывающие на аварийное и ремонтное прошлое машины: Разное расстояние между деталями  Детали отличаются по цвету, не совпадает цвет внешней окраски и на внутренних элементах (в подкапотном пространстве и под уплотнителями)  Отличаются сварные точки в разных проемах  Качество сварных швов разное  На креплениях (винтах, гайках) есть следы воздействия: царапины, сбитая краска  Слишком новая краска для совсем немолодой машины  Коррозия под сиденьями и обшивкой салона и багажного отделения Если есть возможность, то на осмотр лучше взять толщинометр и проверить основные уязвимые места, а также номера агрегатов (если есть) и VIN на предмет целостности металла и точек крепления.
# 25.  На что обратить внимание внутри Салон гораздо больше говорит о возрасте автомобиля и условиях его эксплуатации.
# 26.   Бояться такой техники не нужно, но при этом нужно понимать адекватность цены.
# 27.  Нужно проверить на работоспособность все, что можно: поворотники, свет, омыватели и щетки, музыку, регулировку сидений, подогрев и САЙТ.
# 28.   Если продавец предлагает сделать все через генеральную доверенность — отказывайтесь.
# 29.   Вы можете выйти от нотариуса (он с деньгами, вы с ключами от машины), он вернется туда через 15 минут и отзовет доверенность, со всеми вытекающими последствиями в виде изъятия у вас авто правоохранительными органами.
# 30.   В ДКП и в ПТС при вас должен расписываться только собственник, указанный в ПТС, либо его представитель, у которого на руках нотариальная доверенность.
# 31.   Есть схема, при которой продавец расписывается за реального собственника, через какое-то время тот появляется и требует вернуть ему машину, поскольку ее не продавал и не получал никаких денег, подавая при этом заявления в ГИБДД, суд, прокуратуру и другие инстанции.
# 32.   Всегда указывайте в ДКП только реальную сумму покупки.
# 33.   Если продавец просит указать сумму в 10 000 САЙТ отказывайтесь!
# 34.   Нельзя просто указать в ДКП данные автомобиля, VIN и цвет.
# 35.   Обязательно расписывайте основные параметры приобретаемого транспортного средства (техническое состояние, пробег, битая-не битая и пр).
# 36.   Обязательно отметьте в ДКП, что на машине нет никаких ограничений и она не является предметом залога.
# 37.   Можно сразу использовать образец ДКП с САЙТ.
# 38.   Либо нужно включать в основной договор пункт, что «Настоящий договор является актом приема-передачи транспортного средства» и отдельно вписывать строчки «Деньги получил в размере САЙТ транспортное средство передал» для продавца и «Транспортное средство осмотрено, номерные агрегаты сверены и совпадают, техническое состояние удовлетворяет.
# 39.  Проверьте, нет ли у вас штрафов и задолженностей на сайте Госуслуги.
# 40.   Всегда указывайте только реальную стоимость автомобиля в ДКП.
# 41.   В ПТС надо лично расписаться.
# 42.   Выставляйте машины на продажу только через проверенные автосалоны или используйте схему trade-in у официальных дилеров.
# 43.  Если хоть на миг возникнут сомнения в действиях салона, то нужно разрывать договор, пока есть шанс вернуть машину.
# 44.   Придется выплатить «комиссионные», но зато вы не потеряете автомобиль и более крупную сумму.
# 45.  В крупных городах существует схема, при которой человек сдает машину в автосалон, но тот сначала не может ее продать, потом не может рассчитаться, а потом исчезает.
# 46.   Добиться возврата машины невозможно, поскольку салон оформил все законно, а получить от него деньги нельзя даже по решению суда, потому что их нет, а через какое-то время компания перестает существовать.
# 47.   Не меняйте покупателя в ДКП после совершения сделки.
# 48.   Возьмите за правило: если вы честный продавец, то после оформления ДКП, акта приема-передачи автомобиля и получения денег не нужно идти навстречу покупателю и что-то менять, например, покупателя.
# 49.  Не соглашайтесь получить предоплату, не сообщайте номера своих карт и приходящие от банков пароли Популярная схема обмана, когда звонит якобы покупатель, интересуется машиной и выражает свою готовность ее приобрести перечислением аванса.
# 50.   Если вы попали в ситуацию, которая не описана в нашем коротком справочнике, вы всегда можете найти ответы на возникшие вопросы на форуме.

# %%
k = 0
print(len(a))
print(a[0][0].keys())
for i in a[0]:
    if i['SecondLevel']:
        k += 1
        print("%d. "%(k)+i['Sentence'])
# Out:
# 2
# dict_keys(['Sentence', 'TagUd', 'SecondLevel', 'FirstLevel', 'Relations'])
# 1.  Машина с номерами чужого региона Номер, относящийся к другому региону, в сочетании со следующими признаками должен вас насторожить: — Наличие объявления с этими же фото на Дроме, но по другой цене, возможно, с другими параметрами.
# 2.   Если погасить эту задолженность, то ограничения снимут, и автомобиль можно спокойно ставить на учет.
# 3.  Является ли продавец собственником, и если нет, узнать данные и контакты такового Если продавец является собственником, то это хорошо и с ним можно продолжать диалог о покупке авто.
# 4.   Если же нет, то при нормальной ситуации продавец должен предоставить данные владельца, указанного в ПТС, и его контакт, чтобы тот смог подтвердить правомерность действий доверенного лица и объяснить его появление.
# 5.  », то нужно переходить к следующему объявлению.
# 6.   Это первое, что нужно сделать.
# 7.   Документов, которые надо смотреть, всего три: ПТС (паспорт транспортного средства), СТС (свидетельство о регистрации) и страховка.
# 8.   Год выпуска, марка и модель автомобиля, VIN или номер кузова, указанные в ПТС, должны совпадать с теми, что указаны в объявлении.
# 9.   Все пункты должны совпадать.
# 10.  Если вы решили воспользоваться услугами салона-посредника при продаже авто, то необходимо самому вникнуть в суть процесса: контролировать появление объявления в интернете, через день-другой подъехать в салон, посмотреть, где машина и в каком состоянии.
# 11.   Возьмите за правило: если вы честный продавец, то после оформления ДКП, акта приема-передачи автомобиля и получения денег не нужно идти навстречу покупателю и что-то менять, например, покупателя.
