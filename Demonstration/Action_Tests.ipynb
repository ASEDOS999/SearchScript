# %% [markdown]
# # Tests
#
# ## 1. Trees Constructor
#
# In this part you can see syntactic tree that was built as modification of tree constructed by methods from `isanlp`.

# %%
import sys
sys.path.append('../ScriptExtract/Preprocessing') 
sys.path.append('../Parser/')
import action
text = """
Вам нужно делать это.
"""
root_list = action.construct_tree(text)
def print_tree(n, root):
    kids = root.kids
    if len(kids) != 0:
        for i in kids:
            print('-' * 3 * n, i[0].value.lemma, i[0].value.postag, i[0].value.morph, i[1])
            print_tree(n + 1, i[0])
            
for root in root_list:
    print(action.construct_sentence(root.sentence), '\n')
    print(root.value.lemma, root.value.postag, root.value.morph, 'root')
    print_tree(1, root)
    print('\n'*2)
# Out:
# Вам нужно делать это .
#
# нужно ADV {'fPOS': 'ADV'} root
# --- вы PRON {'fPOS': 'PRON', 'Number': 'Plur', 'Person': '2', 'Case': 'Dat'} obj
# --- делать VERB {'fPOS': 'VERB', 'Aspect': 'Imp', 'Valency': 'TR', 'VerbForm': 'Inf'} xcomp
# ------ это PRON {'fPOS': 'PRON', 'Number': 'Sing', 'Gender': 'Neut', 'Animacy': 'Inan', 'Case': 'Acc'} nsubj
# --- .  {} punct

# %%
import some_reparser as parser
print(text)
parser.extract_semantic_relations(text)
# Out:
# Вам нужно делать это.
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-2-813f65f62abd> in <module>
#       1 import some_reparser as parser
#       2 print(text)
# ----> 3 parser.extract_semantic_relations(text)
#
# ~/Desktop/PROJECTS/ISA_PROJECTS/SearchScript/Parser/some_reparser.py in extract_semantic_relations(text)
#      62                 return None
#      63 def extract_semantic_relations(text):
# ---> 64         json_results = parse(text)
#      65         print(json_results)
#      66         if json_results is None:
#
# ~/Desktop/PROJECTS/ISA_PROJECTS/SearchScript/Parser/some_reparser.py in parse(text)
#      47         params = urllib.parse.urlencode({"PROTOCOL": "JSONRPC"})
#      48         conn = httplib.HTTPConnection(config.webAddress)
# ---> 49         conn.request("POST", config.cgiPath + "?" + params, send_data, headers)
#      50         response = conn.getresponse()
#      51         data = response.read()
#
# ~/anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# ~/anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# ~/anaconda3/lib/python3.7/http/client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# ~/anaconda3/lib/python3.7/http/client.py in connect(self)
#     926         """Connect to the host and port specified in __init__."""
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     930
#
# ~/anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     725
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#     729         raise error("getaddrinfo returns an empty list")
#
# ~/anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# ConnectionRefusedError: [Errno 111] Connection refused

# %%
act = get_actions(root_list[0])
sys.path.append('../')
import ScriptExtract.Preprocessing.TextProcessing as TP
TP.cond_instr(act[0])
# Out:
# True

# %% [markdown]
# ## 2. Action Search And Action's Parameters Search

# %%
from action import get_actions, construct_tree, construct_sentence
from action import descript_role
def show(text, with_tree = False):
    root_list = construct_tree(text)
    actions = []
    for root in root_list:
        print(construct_sentence(root.sentence))
        if with_tree:
            print('\n', root.value.lemma, root.value.postag, root.value.morph, 'root')
            print_tree(1, root)
        actions = get_actions(root)
        for act in actions:
            print('\n', act.name_action)
            dict_ = act.get_inform(False, True, False)[0]
            keys = list(dict_.keys())
            keys.sort()
            for i in keys:
                print(descript_role(i).upper())
                if i != 'VERB':
                    for j in dict_[i]:
                        print('--',j)
                else:
                    print('--',dict_[i])
        print('\n'*2)

# %% [markdown]
# ### 2.1.  Verbs Without Action

# %%
text = """
Он был не высокого роста.
Его борода была очень черной.
Он не мог уже думать об этом.
"""
show(text)
# Out:
# Он был не высокого роста .
#
#  Action1{быть}
# VERB
# -- был
#
#
#
# Его борода была очень черной .
#
#  Action2{быть}
# VERB
# -- была
#
#
#
# Он не мог уже думать об этом .
#
#  Action2{мочь}
# VERB
# -- не мог
# NOMINAL SUBJECT
# -- Он
# PUNCTUATION
# --
# OPEN CLAUSAL COMPLEMENT
# -- уже думать об этом

# %% [markdown]
# ### 2.3. Conjuncted Verbs

# %%
text = """
Маша и Петя гуляли по городу и разговаривали.
Женщины шли к магазину и что-то громко обсуждали.
Он сидел на балконе и наблюдал за гуляющими во дворе детьми.
Миша играл гостям на скрипке, читал свои стихи.
Океан был беспокоен, был сердит.
"""
show(text)
# Out:
# Маша и Петя гуляли по городу и разговаривали .
#
#  Action7{разговаривать}
# VERB
# -- разговаривали
# COORDINATOR
# -- и
# NOMINAL SUBJECT
# -- Маша и Петя
#
#  Action3{гулять}
# VERB
# -- гуляли
# NOMINAL SUBJECT
# -- Маша и Петя
# OBLIQUE NOMINAL
# -- по городу
# PUNCTUATION
# --
#
#
#
# Женщины шли к магазину и что - то громко обсуждали .
#
#  Action9{обсуждать}
# VERB
# -- обсуждали
# ADVERB MODIFIER
# -- громко
# COORDINATOR
# -- и
# MARKER
# -- что - то
#
#  Action1{идти}
# VERB
# -- шли
# NOMINAL SUBJECT
# -- Женщины
# OBLIQUE NOMINAL
# -- к магазину
# PUNCTUATION
# --
#
#
#
# Он сидел на балконе и наблюдал за гуляющими во дворе детьми .
#
#  Action7{гулять}
# VERB
# -- гуляющими
# CASE
# -- за
#
#  Action5{наблюдать}
# VERB
# -- наблюдал
# COORDINATOR
# -- и
# NOMINAL SUBJECT
# -- Он
# OBLIQUE NOMINAL
# -- во дворе детьми
#
#  Action1{сидеть}
# VERB
# -- сидел
# NOMINAL SUBJECT
# -- Он
# OBLIQUE NOMINAL
# -- на балконе
# PUNCTUATION
# --
#
#
#
# Миша играл гостям на скрипке , читал свои стихи .
#
#  Action6{читать}
# VERB
# -- читал
# NOMINAL SUBJECT
# -- Миша
# OBJECT
# -- свои стихи
# PUNCTUATION
# --
#
#  Action1{играть}
# VERB
# -- играл
# INDIRECT OBJECT
# -- гостям
# NOMINAL SUBJECT
# -- Миша
# OBLIQUE NOMINAL
# -- на скрипке
# PUNCTUATION
# --
#
#
#
# Океан был беспокоен , был сердит .
#
#  Action1{быть}
# VERB
# -- был
#
#  Action4{быть}
# VERB
# -- был

# %% [markdown]
# ### 2.4. Verbs With Particle

# %%
text = """
Пробегая мимо, он ни на что не обращал внимания.
Он не приехал вовремя.
Максим не делает домашнее задание.
"""
show(text)
# Out:
# Пробегая мимо , он ни на что не обращал внимания .
#
#  Action0{пробегать}
# VERB
# -- Пробегая
# ADVERB MODIFIER
# -- мимо
# NOMINAL SUBJECT
# -- он
# PUNCTUATION
# --
#
#  Action8{обращать}
# VERB
# -- не обращал
# NOMINAL SUBJECT
# -- он
# OBJECT
# -- внимания
# OBLIQUE NOMINAL
# -- ни на что
# PUNCTUATION
# --
#
#
#
# Он не приехал вовремя .
#
#  Action2{приезжать}
# VERB
# -- не приехал
# NOMINAL SUBJECT
# -- Он
# OBJECT
# -- вовремя
# PUNCTUATION
# --
#
#
#
# Максим не делает домашнее задание .
#
#  Action2{делать}
# VERB
# -- не делает
# NOMINAL SUBJECT
# -- Максим
# OBJECT
# -- домашнее задание
# PUNCTUATION
# --

# %% [markdown]
# ### 2.5. Participles

# %%
text = """
Быстро пробегающий мальчик не обращает на нас внимания.
Пробегавший мимо мальчик не обратил на нас внимания.
Он нашел давно потерянную вещь.
Работа, выполненная мастером, высоко ценится здесь.
Используемый метод оказался не эффективным.
"""
show(text)
# Out:
# Быстро пробегающий мальчик не обращает на нас внимания .
#
#  Action1{пробегать}
# VERB
# -- пробегающий
# ADVERB MODIFIER
# -- Быстро
# SUBJECT
# -- мальчик
#
#  Action4{обращать}
# VERB
# -- не обращает
# NOMINAL SUBJECT
# -- мальчик
# OBLIQUE NOMINAL
# -- на нас внимания
# PUNCTUATION
# --
#
#
#
# Пробегавший мимо мальчик не обратил на нас внимания .
#
#  Action0{пробегать}
# VERB
# -- Пробегавший
# ADVERB MODIFIER
# -- мимо
# SUBJECT
# -- мальчик
#
#  Action4{обращать}
# VERB
# -- не обратил
# NOMINAL SUBJECT
# -- мальчик
# OBLIQUE NOMINAL
# -- на нас внимания
# PUNCTUATION
# --
#
#
#
# Он нашел давно потерянную вещь .
#
#  Action3{потерять}
# VERB
# -- потерянную
# SUBJECT
# -- давно вещь
#
#  Action1{находить}
# VERB
# -- нашел
# NOMINAL SUBJECT
# -- Он
# OBJECT
# -- давно вещь
# PUNCTUATION
# --
#
#
#
# Работа , выполненная мастером , высоко ценится здесь .
#
#  Action2{выполнять}
# VERB
# -- выполненная
# INDIRECT OBJECT
# -- мастером
# PUNCTUATION
# --
# --
# SUBJECT
# -- Работа
#
#  Action6{цениться}
# VERB
# -- ценится
# ADVERB MODIFIER
# -- здесь
# COORDINATOR
# -- высоко
# NOMINAL SUBJECT
# -- Работа
# PUNCTUATION
# --
#
#
#
# Используемый метод оказался не эффективным .
#
#  Action0{использовать}
# VERB
# -- Используемый
# SUBJECT
# -- метод
#
#  Action2{оказываться}
# VERB
# -- оказался
# ADVERB MODIFIER
# -- не эффективным
# NOMINAL SUBJECT
# -- метод
# PUNCTUATION
# --

# %% [markdown]
# ### 2.6. Different Examples

# %%
text = """
Он благополучно избегнул встречи с своею хозяйкой на лестнице.
Справа из леса вышли двое, ступили на обочину и остановились, глядя в мою сторону.
Один из них поднял руку.
Тот, что поднимал руку,  просунул в машину  смуглое  горбоносое  лицо  и  спросил улыбаясь...
Их лица понравились мне, и я остановился.
"""
show(text)
# Out:
# Он благополучно избегнул встречи с своею хозяйкой на лестнице .
#
#  Action2{избегать}
# VERB
# -- избегнул
# ADVERB MODIFIER
# -- благополучно
# NOMINAL SUBJECT
# -- Он
# OBJECT
# -- встречи с своею хозяйкой
# OBLIQUE NOMINAL
# -- на лестнице
# PUNCTUATION
# --
#
#
#
# Справа из леса вышли двое , ступили на обочину и остановились , глядя в мою сторону .
#
#  Action12{глядеть}
# VERB
# -- глядя
# OBLIQUE NOMINAL
# -- в мою сторону
# PUNCTUATION
# --
#
#  Action10{останавливаться}
# VERB
# -- остановились
# COORDINATOR
# -- и
# OBLIQUE NOMINAL
# -- на обочину
#
#  Action6{ступать}
# VERB
# -- ступили
# NUMERIC MODIFIER
# -- двое
# PUNCTUATION
# --
#
#  Action3{выходить}
# VERB
# -- вышли
# ADVERB MODIFIER
# -- Справа
# OBLIQUE NOMINAL
# -- из леса
# PUNCTUATION
# --
#
#
#
# Один из них поднял руку .
#
#  Action3{подымать}
# VERB
# -- поднял
# NOMINAL SUBJECT
# -- Один из них
# OBJECT
# -- руку
# PUNCTUATION
# --
#
#
#
# Тот , что поднимал руку , просунул в машину смуглое горбоносое лицо и спросил улыбаясь ... Их лица понравились мне , и я остановился .
#
#  Action3{подымать}
# VERB
# -- поднимал
# MARKER
# -- что
# OBJECT
# -- руку
# PUNCTUATION
# --
# --
#
#  Action14{улыбаться}
# VERB
# -- улыбаясь
# NOMINAL SUBJECT
# -- Их лица
# PUNCTUATION
# --
#
#  Action23{останавливаться}
# VERB
# -- остановился
# COORDINATOR
# -- и
# NOMINAL SUBJECT
# -- я
# PUNCTUATION
# --
#
#  Action18{понравиться}
# VERB
# -- понравились
# INDIRECT OBJECT
# -- мне
# NOMINAL SUBJECT
# -- Их лица
#
#  Action13{спрашивать}
# VERB
# -- спросил
# COORDINATOR
# -- и
# NOMINAL SUBJECT
# -- Тот
#
#  Action6{просовывать}
# VERB
# -- просунул
# NOMINAL SUBJECT
# -- Тот
# OBJECT
# -- смуглое горбоносое лицо
# OBLIQUE NOMINAL
# -- в машину
# PUNCTUATION
# --

# %% [markdown]
# ## 3. Actions tree

# %%
from action import get_actions_tree
def print_actions_tree(root, n = 0, depend = 'root'):
    print('--' * n, root.value.name_action, depend)
    for i in root.kids:
        print_actions_tree(i[0], n + 1, i[1])

# %%
text = """
Справа из леса вышли двое, ступили на обочину и остановились, глядя в мою сторону.
Тот, что поднимал руку,  просунул в машину  смуглое  горбоносое  лицо  и  спросил улыбаясь.
Глядя на меня, он задал вопрос.
Пробегавший мимо мальчик не обратил на нас внимания.
"""
root_list = construct_tree(text)
for root in root_list:
    print(action.construct_sentence(root.sentence))
    print_actions_tree(get_actions_tree(root))
    print('\n')
# Out:
# Справа из леса вышли двое , ступили на обочину и остановились , глядя в мою сторону .
#  ROOT root
# -- Action3{выходить} ROOT
# ---- Action6{ступать} conj{without_marks}
# ------ Action10{останавливаться} conj{и}
# -------- Action12{глядеть} advcl{without_marks}
#
#
# Тот , что поднимал руку , просунул в машину смуглое горбоносое лицо и спросил улыбаясь .
#  ROOT root
# -- Action6{просовывать} ROOT
# ---- Action3{подымать} nondet
# ---- Action13{спрашивать} conj{и}
# ------ Action14{улыбаться} advcl{without_marks}
#
#
# Глядя на меня , он задал вопрос .
#  ROOT root
# -- Action5{задавать} ROOT
# ---- Action0{глядеть} advcl{without_marks}
#
#
# Пробегавший мимо мальчик не обратил на нас внимания .
#  ROOT root
# -- Action4{обращать} ROOT
# ---- Action0{пробегать} nondet
