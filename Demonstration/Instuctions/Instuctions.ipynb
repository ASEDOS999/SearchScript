# %% [markdown]
# # Extracting Instruction
#
# It demonstrates a workability of our approach to extract action-instructions from text. For each test document there is a set of names of extracted action and for each action there is a sentence involving the action.
#
# All documents was taken from [this google-disk](https://drive.google.com/drive/folders/1JUv5yHlHYR6hHf3d6MhVKiFjo5Zc4hEN). There are original documents names and links to them below.

# %%
import sys
sys.path.append('../../ScriptExtract/Preprocessing')

from TextProcessing import text_separation as GC
#from TextProcessing import research_list, show

# %% [markdown]
# ## 1. File 'Выбираем автомобиль.txt'
#
# The original is [Выбираем автомобиль](https://docs.google.com/document/d/1WHttYDN6ZWGcWpCiFuwlUecnmSMC7D6fwo3uvui8psY/edit).

# %%
handle = open("Выбираем автомобиль.txt", "r")
text = handle.read()
handle.close()

list_ = GC(text).get_list_of_tree()

# %%
list_
# Out:
# [{'Type': 'paragraph',
#   'Section': None,
#   'Text': '\ufeffВыбираем автомобиль\n',
#   'Sentences': [21, 22],
#   'Synt tree': [<action.tree at 0x7f7fe827ccf8>],
#   'Action tree': [<action.tree at 0x7f7fe8074ef0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': '\t Автомобиль и Я \n\n',
#   'Sentences': [18, 19, 20],
#   'Synt tree': [<action.tree at 0x7f7fe827ce10>],
#   'Action tree': [<action.tree at 0x7f7fe8074a58>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': '\tВыбор марки и модели\n',
#   'Sentences': [22, 23],
#   'Synt tree': [<action.tree at 0x7f7fe827c940>],
#   'Action tree': [<action.tree at 0x7f7fe8074c50>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'На что у нас хватает?\n',
#   'Sentences': [21, 22, 23],
#   'Synt tree': [<action.tree at 0x7f7fe8287978>],
#   'Action tree': [<action.tree at 0x7f7fe8074a20>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Большинство автовладельцев начинает выбор именно с этого вопроса. Определить свою «ценовую категорию», а потом выбрать в этой категории лучшее – тактика разумная. А вот покупать авто на последние «кровные» довольно рискованно. Особенно, если это автомобиль с пробегом.\n',
#   'Sentences': [65, 162, 226, 268, 269, 270],
#   'Synt tree': [<action.tree at 0x7f7fe8287518>,
#    <action.tree at 0x7f7fe8287780>,
#    <action.tree at 0x7f7ff85659b0>,
#    <action.tree at 0x7f7fe828ef60>],
#   'Action tree': [<action.tree at 0x7f7fe8074b70>,
#    <action.tree at 0x7f7fe8074f60>,
#    <action.tree at 0x7f7fe80bde48>,
#    <action.tree at 0x7f7fe80bd3c8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'При подсчете нужной суммы денег обязательно учтите расходы на техническое обслуживание машины и дополнительное оборудование, которое потребуется сразу же после покупки.\n',
#   'Sentences': [168, 169, 170],
#   'Synt tree': [<action.tree at 0x7f7fe8297470>],
#   'Action tree': [<action.tree at 0x7f7fe80bdc88>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Если вы сомневаетесь в выборе, съездите в автосалон, на авторынок. Присмотритесь к разным вариантам. Посидите за рулем. Если предоставляется тест-драйв, обязательно им воспользуйтесь. Прислушайтесь к своим ощущениям. Сравнивайте.\n',
#   'Sentences': [66, 100, 119, 183, 216, 229, 230, 231],
#   'Synt tree': [<action.tree at 0x7f7fe8287c88>,
#    <action.tree at 0x7f7fe8291c18>,
#    <action.tree at 0x7f7fe8297f28>,
#    <action.tree at 0x7f7fe829a2b0>,
#    <action.tree at 0x7f7fe82ec240>,
#    <action.tree at 0x7f7fe827c9b0>],
#   'Action tree': [<action.tree at 0x7f7fe807b160>,
#    <action.tree at 0x7f7fe807b080>,
#    <action.tree at 0x7f7fe807b320>,
#    <action.tree at 0x7f7fe807b518>,
#    <action.tree at 0x7f7fe807b470>,
#    <action.tree at 0x7f7fe807b668>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Универсального критерия не существует\n',
#   'Sentences': [38, 39],
#   'Synt tree': [<action.tree at 0x7f7fe829ac88>],
#   'Action tree': [<action.tree at 0x7f7fe807b588>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Покупать следует то, что по душе и по карману именно вам. Старайтесь не упускать из виду практические соображения. Машина может очень нравиться, но совершенно не соответствовать вашим реальным нуждам.\n',
#   'Sentences': [57, 114, 200, 201, 202],
#   'Synt tree': [<action.tree at 0x7f7fe829a748>,
#    <action.tree at 0x7f7fe82915f8>,
#    <action.tree at 0x7f7fe829fc88>],
#   'Action tree': [<action.tree at 0x7f7fe807b7f0>,
#    <action.tree at 0x7f7fe807b710>,
#    <action.tree at 0x7f7fe807b9b0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'К сожалению, оптимального автомобиля на все случаи жизни просто не бывает. Вам придется принимать решение в пользу более стильного, или - более проходимого, или - более вместительного, или - более САЙТ. и так далее.\n',
#   'Sentences': [74, 202, 215, 216, 217],
#   'Synt tree': [<action.tree at 0x7f7fe82a3c50>,
#    <action.tree at 0x7f7fe8288240>,
#    <action.tree at 0x7f7fe8288c18>],
#   'Action tree': [<action.tree at 0x7f7fe807b8d0>,
#    <action.tree at 0x7f7fe807bba8>,
#    <action.tree at 0x7f7fe807ba90>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Перед покупкой хорошо бы также изучить опыт владельцев данной марки. Где взять эту информацию? В Интернете, конечно :).\n',
#   'Sentences': [68, 94, 119, 120, 121],
#   'Synt tree': [<action.tree at 0x7f7fe82a9828>,
#    <action.tree at 0x7f7fe8288ac8>,
#    <action.tree at 0x7f7fe82a9d30>],
#   'Action tree': [<action.tree at 0x7f7fe807bc18>,
#    <action.tree at 0x7f7fe807be10>,
#    <action.tree at 0x7f7fe807bda0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Если вы подбираете автомобиль по соотношению цена/качество, то по возможности выбирайте автопроизводителя с именем и марку, пользующуюся популярностью у покупателей. Не прогадаете.\n',
#   'Sentences': [165, 180, 181, 182],
#   'Synt tree': [<action.tree at 0x7f7fe82a9748>,
#    <action.tree at 0x7f7fe8297da0>],
#   'Action tree': [<action.tree at 0x7f7fe807bcc0>,
#    <action.tree at 0x7f7fe80e89e8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Чтобы упростить себе выбор из двух равнозначных моделей, сравните цены на плановое техническое обслуживание и запчасти, а также их доступность.\n',
#   'Sentences': [143, 144, 145],
#   'Synt tree': [<action.tree at 0x7f7fe82430f0>],
#   'Action tree': [<action.tree at 0x7f7fe80e8c50>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': '© САЙТ\n',
#   'Sentences': [7, 8],
#   'Synt tree': [<action.tree at 0x7f7fe82a3e80>],
#   'Action tree': [<action.tree at 0x7f7fe80e8320>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Где покупать автомобиль?\n',
#   'Sentences': [24, 25, 26],
#   'Synt tree': [<action.tree at 0x7f7fe82a3278>],
#   'Action tree': [<action.tree at 0x7f7fe80e8470>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Ответ на этот вопрос для каждого свой. Одни ищут там, где меньше цена, другие - там, где лучше сервис, где есть хорошая гарантия и бонусы.\n',
#   'Sentences': [38, 138, 139, 140],
#   'Synt tree': [<action.tree at 0x7f7fe8291780>,
#    <action.tree at 0x7f7fe82443c8>],
#   'Action tree': [<action.tree at 0x7f7fe80e8b38>,
#    <action.tree at 0x7f7fe80e8160>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Всю информацию по ценам на выбранную модель вы найдете в прайсах автосалонов и в текстах объявлений. Наиболее комфортные условия в плане обслуживания и гарантии – конечно же, у официального дилера.\n',
#   'Sentences': [100, 197, 198, 199],
#   'Synt tree': [<action.tree at 0x7f7fe824a9e8>,
#    <action.tree at 0x7f7fe823d3c8>],
#   'Action tree': [<action.tree at 0x7f7fe80dc6d8>,
#    <action.tree at 0x7f7fe80dcbe0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Уточните стоимость дополнительного оборудования: ковриков, магнитолы, парктроников, защиты картера*, сигнализации. Иногда цены могут значительно различаться в зависимости от автосалона. А некоторые вещи попроще можно приобрести и вовсе в магазине автозапчастей. Обычно даже «фирменные» комплектующие там дешевле.\n',
#   'Sentences': [114, 185, 261, 312, 313, 314],
#   'Synt tree': [<action.tree at 0x7f7fe82a9eb8>,
#    <action.tree at 0x7f7fe823d048>,
#    <action.tree at 0x7f7fe8251e10>,
#    <action.tree at 0x7f7fe8230208>],
#   'Action tree': [<action.tree at 0x7f7fe80dc278>,
#    <action.tree at 0x7f7fe80dc5f8>,
#    <action.tree at 0x7f7fe80ed240>,
#    <action.tree at 0x7f7fe80ed940>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'В последнее время представительства солидных марок стали предлагать автомобили с пробегом. У них, как правило, все авто перед поступлением проходят всевозможные проверки, а значит, шанс приобрести криминальный или «убитый» автомобиль -  минимален.\n',
#   'Sentences': [90, 247, 248, 249],
#   'Synt tree': [<action.tree at 0x7f7fe8262390>,
#    <action.tree at 0x7f7fe8263550>],
#   'Action tree': [<action.tree at 0x7f7fe80ed7f0>,
#    <action.tree at 0x7f7fe80edb70>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Вообще, качество продаваемых машин сильно зависит от имени и размера автосалона. Официальные представители обычно следят за своей репутацией и чаще всего совершенно не заинтересованы обманывать покупателя. А в мелких забегаловках можно такое приобрести… Так что держите ухо востро.\n',
#   'Sentences': [80, 205, 281, 282, 283],
#   'Synt tree': [<action.tree at 0x7f7fe8258b38>,
#    <action.tree at 0x7f7fe8267ba8>,
#    <action.tree at 0x7f7fe8263eb8>],
#   'Action tree': [<action.tree at 0x7f7fe80edda0>,
#    <action.tree at 0x7f7fe80e6d68>,
#    <action.tree at 0x7f7fe80e69e8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'К весне спрос на автомобили растет, а осенью – падает. Выводы делайте сами. :)\n',
#   'Sentences': [54, 75, 79, 80],
#   'Synt tree': [<action.tree at 0x7f7fe81f15c0>,
#    <action.tree at 0x7f7fe829f4a8>,
#    <action.tree at 0x7f7fe82a3208>],
#   'Action tree': [<action.tree at 0x7f7fe80e6fd0>,
#    <action.tree at 0x7f7fe807f0f0>,
#    <action.tree at 0x7f7fe807f240>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': '© САЙТ\n',
#   'Sentences': [7, 8],
#   'Synt tree': [<action.tree at 0x7f7fe81f1b00>],
#   'Action tree': [<action.tree at 0x7f7fe807f320>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Новый или подержанный?\n',
#   'Sentences': [22, 23, 24],
#   'Synt tree': [<action.tree at 0x7f7fe81f11d0>],
#   'Action tree': [<action.tree at 0x7f7fe807f400>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Если новая машина человеку не по карману, но уж очень приглянулась, то его начинают посещать мысли о покупке автомобиля той же модели, но с пробегом.\n',
#   'Sentences': [149, 150, 151],
#   'Synt tree': [<action.tree at 0x7f7fe81ff160>],
#   'Action tree': [<action.tree at 0x7f7fe807f4e0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Тут есть свой резон. Не успев выехать за ворота автосалона, новый автомобиль стремительно начинает падать в цене.  Сплошь и рядом, задумав продать «почти новую» машину, владелец бывает неприятно удивлен тем, как сильно она подешевела со дня покупки. Да я ж почти на ней и не ездил! Как же так?\n',
#   'Sentences': [20, 113, 249, 281, 293, 294, 295],
#   'Synt tree': [<action.tree at 0x7f7fe824af60>,
#    <action.tree at 0x7f7fe82628d0>,
#    <action.tree at 0x7f7fe8202828>,
#    <action.tree at 0x7f7fe82021d0>,
#    <action.tree at 0x7f7fe81f79e8>],
#   'Action tree': [<action.tree at 0x7f7fe807f748>,
#    <action.tree at 0x7f7fe807f908>,
#    <action.tree at 0x7f7fe807fa90>,
#    <action.tree at 0x7f7fe807fc50>,
#    <action.tree at 0x7f7fe807fcf8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'А вот так! Например, в правилах добровольного страхования одной из крупных страховых компаний указано, что, с учетом нормы амортизационного износа, любой застрахованный автомобиль теряет в стоимости:\n',
#   'Sentences': [10, 200, 201],
#   'Synt tree': [<action.tree at 0x7f7fe8202c88>,
#    <action.tree at 0x7f7fe82165c0>],
#   'Action tree': [<action.tree at 0x7f7fe807fd68>,
#    <action.tree at 0x7f7fe807fe48>]},
#  {'Type': 'list',
#   'Elements': ['* за первый год 20 % от страховой суммы;\n',
#    '* за первый год 20 % от страховой суммы;\n',
#    '* за второй 15% ;\n',
#    '* за третий и последующие годы по 10 %.\n'],
#   'Sentences': [[41, 42], [41, 42], [18, 19], [39, 40, 41]],
#   'Text': '* за первый год 20 % от страховой суммы;\n * за первый год 20 % от страховой суммы;\n * за второй 15% ;\n * за третий и последующие годы по 10 %.\n',
#   'Synt tree': [<action.tree at 0x7f7fe8202ba8>,
#    <action.tree at 0x7f7fe820db38>,
#    <action.tree at 0x7f7fe8219748>,
#    <action.tree at 0x7f7fe8219a58>],
#   'Action tree': [<action.tree at 0x7f7fe807ff60>,
#    <action.tree at 0x7f7fe80a3048>,
#    <action.tree at 0x7f7fe80a30b8>,
#    <action.tree at 0x7f7fe80a3128>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Так ли это, можем проверить нехитрым способом. Открываем объявления о продаже авто и сравниваем цены.\n',
#   'Sentences': [46, 101, 102, 103],
#   'Synt tree': [<action.tree at 0x7f7fe82169e8>,
#    <action.tree at 0x7f7fe820d0b8>],
#   'Action tree': [<action.tree at 0x7f7fe80a31d0>,
#    <action.tree at 0x7f7fe80a32e8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Конечно, новую машину покупать спокойней и приятнее. Но приведенный выше расчет стоит обдумать, если вы ограничены в средствах.\n',
#   'Sentences': [52, 127, 128, 129],
#   'Synt tree': [<action.tree at 0x7f7fe8219898>,
#    <action.tree at 0x7f7fe821f160>],
#   'Action tree': [<action.tree at 0x7f7fe80a33c8>,
#    <action.tree at 0x7f7fe80a34e0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'А что САЙТ\n',
#   'Sentences': [11, 12],
#   'Synt tree': [<action.tree at 0x7f7fe8219978>],
#   'Action tree': [<action.tree at 0x7f7fe80a35f8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Больше всего боятся покупать подержанный автомобиль из-за страха нарваться на «убитую» машину. Умельцы могут восстановить внешний вид авто даже после серьезного ДТП. Сверкающее чудо техники может оказаться склепанным из перекрашенных «бэушных» деталей. Если приобретешь такого «кота в мешке»  - мало не покажется.\n',
#   'Sentences': [94, 165, 252, 313, 314, 315],
#   'Synt tree': [<action.tree at 0x7f7fe821f470>,
#    <action.tree at 0x7f7fe8215518>,
#    <action.tree at 0x7f7fe8228828>,
#    <action.tree at 0x7f7fe822ceb8>],
#   'Action tree': [<action.tree at 0x7f7fe80a36a0>,
#    <action.tree at 0x7f7fe80a37b8>,
#    <action.tree at 0x7f7fe80a3940>,
#    <action.tree at 0x7f7fe80a3b38>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Впрочем, «убить» машину можно и не попадая в аварии – просто в результате небрежного отношения и неумелой эксплуатации.\n',
#   'Sentences': [119, 120, 121],
#   'Synt tree': [<action.tree at 0x7f7fe81ba2b0>],
#   'Action tree': [<action.tree at 0x7f7fe80a3c88>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Однако при покупке и эту проблему решить можно. Главное - найти грамотного специалиста по диагностике. Обычно в любом приличном автосервисе можно пройти диагностику кузова, двигателя, подвески. И при покупке автомобиля с пробегом лучше всего это проделать.\n',
#   'Sentences': [47, 102, 193, 256, 257, 258],
#   'Synt tree': [<action.tree at 0x7f7fe81ba9b0>,
#    <action.tree at 0x7f7fe81b1eb8>,
#    <action.tree at 0x7f7fe81bb550>,
#    <action.tree at 0x7f7fe822ca20>],
#   'Action tree': [<action.tree at 0x7f7fe80a3da0>,
#    <action.tree at 0x7f7fe80a3e48>,
#    <action.tree at 0x7f7fe80a3ef0>,
#    <action.tree at 0x7f7fe80a3f98>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Есть также специализированные автосервисы, производящие экспертизу технического состояния всего автомобиля на очень высоком уровне и на оборудовании, которым не пользуются в обычных мастерских. Стоит это не так дорого, как может показаться.\n',
#   'Sentences': [193, 240, 241, 242],
#   'Synt tree': [<action.tree at 0x7f7fe81b1128>,
#    <action.tree at 0x7f7fe8216828>],
#   'Action tree': [<action.tree at 0x7f7fe80ab080>,
#    <action.tree at 0x7f7fe80ab240>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Результаты диагностики обычно поражают даже самого продавца (особенно, если он что-то пытался скрыть). Например, по результату такого обследования можно узнать о повышенном расходе масла и определить степень износа двигателя.\n',
#   'Sentences': [102, 225, 226, 227],
#   'Synt tree': [<action.tree at 0x7f7fe81d1320>,
#    <action.tree at 0x7f7fe81c9208>],
#   'Action tree': [<action.tree at 0x7f7fe80ab390>,
#    <action.tree at 0x7f7fe80ab4e0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': '© САЙТ\n',
#   'Sentences': [7, 8],
#   'Synt tree': [<action.tree at 0x7f7fe81d1fd0>],
#   'Action tree': [<action.tree at 0x7f7fe80ab588>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Юридическая «чистота»\n',
#   'Sentences': [22, 23],
#   'Synt tree': [<action.tree at 0x7f7fe81d19e8>],
#   'Action tree': [<action.tree at 0x7f7fe80ab5f8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Вопрос о подлинности и юридической «чистоте» документов на б/у авто также нельзя оставить без внимания. Даже «пробив» машину по гаишной базе на угон, нельзя быть на сто процентов уверенным в том, что автомобиль не был угнан. Номера могут быть искусно перебиты под реально существующую «некриминальную» машину. А иногда бывают ситуации, когда на момент покупки с автомобилем все в порядке, а через какое-то время он обнаруживается «в угоне».\n',
#   'Sentences': [103, 224, 309, 440, 441, 442],
#   'Synt tree': [<action.tree at 0x7f7fe81d8cf8>,
#    <action.tree at 0x7f7fe81e2438>,
#    <action.tree at 0x7f7fe81bae48>,
#    <action.tree at 0x7f7fe81e4320>],
#   'Action tree': [<action.tree at 0x7f7fe80ab6a0>,
#    <action.tree at 0x7f7fe80ab780>,
#    <action.tree at 0x7f7fe80ab9e8>,
#    <action.tree at 0x7f7fe80abba8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Если новая машина была продана через официального дилера на территории РФ, то «историю» автомобиля узнать не так сложно, поскольку обычно все обращения по поводу неисправностей и ТО регистрируются на фирме в клиентской базе данных. Из которой, кстати, можно узнать, когда и какие работы проводились с автомобилем, вплоть до рихтовочно-покрасочных. Очень удобно.\n',
#   'Sentences': [231, 347, 361, 362, 363],
#   'Synt tree': [<action.tree at 0x7f7fe81769b0>,
#    <action.tree at 0x7f7fe81eae80>,
#    <action.tree at 0x7f7fe8176ef0>],
#   'Action tree': [<action.tree at 0x7f7fe80abdd8>,
#    <action.tree at 0x7f7fe80abf60>,
#    <action.tree at 0x7f7fe8036080>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Если автомобиль уже не на гарантии, то полной информации о нем у дилера может не оказаться, хотя из его базы и в этом случае многое можно узнать. Единственное, о чем нужно помнить - эту информацию предоставляют только законному владельцу и только там, где обслуживался автомобиль. В сервисной книжке обязательно должны быть эти данные.\n',
#   'Sentences': [145, 280, 335, 336, 337],
#   'Synt tree': [<action.tree at 0x7f7fe81d85c0>,
#    <action.tree at 0x7f7fe8173668>,
#    <action.tree at 0x7f7fe81bee80>],
#   'Action tree': [<action.tree at 0x7f7fe8036160>,
#    <action.tree at 0x7f7fe8036240>,
#    <action.tree at 0x7f7fe8036438>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Два слова об угонах\n',
#   'Sentences': [20, 21],
#   'Synt tree': [<action.tree at 0x7f7fe81817b8>],
#   'Action tree': [<action.tree at 0x7f7fe8036518>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Автомобиль, к сожалению, иногда может переместиться в неизвестном направлении без ведома своего владельца. Поэтому еще перед покупкой нужно подумать о парковочном месте (или гараже) и определиться с охранной системой, (сигналицией, механическими блокираторами).\n',
#   'Sentences': [106, 261, 262, 263],
#   'Synt tree': [<action.tree at 0x7f7fe81ddf28>,
#    <action.tree at 0x7f7fe818d400>],
#   'Action tree': [<action.tree at 0x7f7fe80365c0>,
#    <action.tree at 0x7f7fe80366a0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Для предварительной оценки расходов на защиту своего любимца можно ознакомиться с рейтингами угоняемых автомобилей, размещенных в сети Интернет.\n',
#   'Sentences': [144, 145, 146],
#   'Synt tree': [<action.tree at 0x7f7fe8195828>],
#   'Action tree': [<action.tree at 0x7f7fe8036780>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Но лучшим средством в борьбе с угонщиками будет, конечно же, страхование от ущерба (КАСКО).\n',
#   'Sentences': [91, 92, 93],
#   'Synt tree': [<action.tree at 0x7f7fe8183908>],
#   'Action tree': [<action.tree at 0x7f7fe80368d0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': '© САЙТ\n',
#   'Sentences': [7, 8],
#   'Synt tree': [<action.tree at 0x7f7fe8183b70>],
#   'Action tree': [<action.tree at 0x7f7fe80369e8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Зависимость расходов на обслуживание от возраста машины\n',
#   'Sentences': [56, 57],
#   'Synt tree': [<action.tree at 0x7f7fe8187780>],
#   'Action tree': [<action.tree at 0x7f7fe8036a58>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Перед покупкой автомобиля с пробегом зададим себе важный вопрос: какой автомобиль выгоднее содержать: новый или подержанный (б/у)?\n',
#   'Sentences': [130, 131, 132],
#   'Synt tree': [<action.tree at 0x7f7fe8195e10>],
#   'Action tree': [<action.tree at 0x7f7fe8036b00>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Для начала определимся, какой автомобиль будем называть новым, а какой - старым. Это тоже вопрос непростой.\n',
#   'Sentences': [80, 107, 108, 109],
#   'Synt tree': [<action.tree at 0x7f7fe81a55f8>,
#    <action.tree at 0x7f7fe818dd68>],
#   'Action tree': [<action.tree at 0x7f7fe8036c18>,
#    <action.tree at 0x7f7fe8036cf8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'На многие авто производитель дает гарантию в три года или до пробега в сто тысяч км, смотря что наступит раньше. Иногда этот срок может доходить даже до пяти лет. На срок гарантии владелец освобождается от оплаты ремонта основных и дорогостоящих деталей, при условии, что поломка произошла по вине производителя. Обычно на время гарантии о серьезных неисправностях можно забыть. Спокойствие владельца – большой плюс гарантийного обслуживания. А вот один из его бесспорных минусов: в период действия гарантии владельца вынуждают проходить необоснованно дорогие ТО и только в авторизованном сервисе.\n',
#   'Sentences': [112, 162, 312, 378, 442, 597, 598, 599],
#   'Synt tree': [<action.tree at 0x7f7fe81ae278>,
#    <action.tree at 0x7f7fe81e2fd0>,
#    <action.tree at 0x7f7fe81af2b0>,
#    <action.tree at 0x7f7fe81aee48>,
#    <action.tree at 0x7f7fe81ab3c8>,
#    <action.tree at 0x7f7fe81394e0>],
#   'Action tree': [<action.tree at 0x7f7fe8036dd8>,
#    <action.tree at 0x7f7fe8036ef0>,
#    <action.tree at 0x7f7fe8040048>,
#    <action.tree at 0x7f7fe8040160>,
#    <action.tree at 0x7f7fe8040208>,
#    <action.tree at 0x7f7fe80402b0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Как правило, по истечении гарантийного срока, а если еще точнее, то в районе 90 тысяч км пробега ваш автомобиль ждет ТО, которое обойдется намного дороже прежних. (цены на различные плановые ТО всегда можно уточнить у официального дилера).\n',
#   'Sentences': [162, 239, 240, 241],
#   'Synt tree': [<action.tree at 0x7f7fe819cbe0>,
#    <action.tree at 0x7f7fe8140b70>],
#   'Action tree': [<action.tree at 0x7f7fe8040390>,
#    <action.tree at 0x7f7fe8040470>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Ближе к отметке в 100-120 тыс. км приготовьтесь к замене сцепления и другим серьезным процедурам, вплоть до переборки ходовой и замены катализатора, поскольку срок службы последнего редко превышает 120-140 тыс. И это уже существенные расходы. Поэтому хозяева часто стараются избавиться от машины именно к этому сроку, чтобы переложить дорогостоящий ремонт на следующего владельца. (Хотя многие  предпочитают менять авто именно потому, что заканчивается гарантия).\n',
#   'Sentences': [30, 210, 242, 380, 463, 464, 465],
#   'Synt tree': [<action.tree at 0x7f7fe81affd0>,
#    <action.tree at 0x7f7fe81a5c50>,
#    <action.tree at 0x7f7fe8148c50>,
#    <action.tree at 0x7f7fe814a5f8>,
#    <action.tree at 0x7f7fe8154828>],
#   'Action tree': [<action.tree at 0x7f7fe8040550>,
#    <action.tree at 0x7f7fe8040668>,
#    <action.tree at 0x7f7fe8040748>,
#    <action.tree at 0x7f7fe80407f0>,
#    <action.tree at 0x7f7fe80408d0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Подытожим: пока действует гарантия, автомобиль условно можно называть новым. По истечении этого срока чаще всего требуется больший уход и, как следствие, большие расходы. А вот б/у автомобиль, у которого пробег приблизился к 160-180 тысячам километров (у таких машин возраст обычно не моложе 6-8 лет) я бы назвал уже старым. Обычно к этому моменту приближается второе дорогостоящее ТО. Да и состояние лакокрасочного покрытия начинает выдавать возраст. Многочисленные сколы – это само собой, но кое-где уже можно разглядеть и ржавчину. Перекрашенные автомобили не в счет :)\n',
#   'Sentences': [76, 170, 324, 385, 451, 534, 573, 574],
#   'Synt tree': [<action.tree at 0x7f7fe8148b00>,
#    <action.tree at 0x7f7fe81556d8>,
#    <action.tree at 0x7f7fe816af60>,
#    <action.tree at 0x7f7fe816d128>,
#    <action.tree at 0x7f7fe8168da0>,
#    <action.tree at 0x7f7fe8140828>,
#    <action.tree at 0x7f7fe8154e48>],
#   'Action tree': [<action.tree at 0x7f7fe8040a58>,
#    <action.tree at 0x7f7fe8040ba8>,
#    <action.tree at 0x7f7fe8040cc0>,
#    <action.tree at 0x7f7fe8040e10>,
#    <action.tree at 0x7f7fe8040ef0>,
#    <action.tree at 0x7f7fe8040f98>,
#    <action.tree at 0x7f7fe80490f0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Ну, а если пробег или возраст еще больше  - не стоит брать машину, если под рукой нет знакомого «самоделкина». Ибо как часто такой автомобиль будет ломаться - можно только гадать. Эксплуатация б/у автомобиля со значительным пробегом частенько встает хозяину в копеечку. Содержать такую машину выгодно, только если ремонтировать и обслуживать ее своими руками. \n',
#   'Sentences': [110, 179, 269, 359, 361, 362],
#   'Synt tree': [<action.tree at 0x7f7fe80fb6a0>,
#    <action.tree at 0x7f7fe8155ef0>,
#    <action.tree at 0x7f7fe80fbb70>,
#    <action.tree at 0x7f7fe80ff860>],
#   'Action tree': [<action.tree at 0x7f7fe80491d0>,
#    <action.tree at 0x7f7fe80492b0>,
#    <action.tree at 0x7f7fe8049390>,
#    <action.tree at 0x7f7fe8049438>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Кстати: мы говорим о реальном пробеге, а не о «скрученном». А «скручивать» одометр* у нас в стране, вообще-то, традиция. Несмотря на это, опытные механики по косвенным признакам могут довольно точно определить пробег, если автомобиль не слишком старый.\n',
#   'Sentences': [59, 120, 252, 253, 254],
#   'Synt tree': [<action.tree at 0x7f7fe813fc88>,
#    <action.tree at 0x7f7fe8167e48>,
#    <action.tree at 0x7f7fe8108668>],
#   'Action tree': [<action.tree at 0x7f7fe80494e0>,
#    <action.tree at 0x7f7fe80495c0>,
#    <action.tree at 0x7f7fe80496a0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Обычно среднестатистический автомобиль пробегает в год не менее 30-40 тысяч км. Зная эту примерную цифру и возраст авто, минимальный пробег можно приблизительно прикинуть и самому.\n',
#   'Sentences': [79, 180, 181, 182],
#   'Synt tree': [<action.tree at 0x7f7fe810e4e0>,
#    <action.tree at 0x7f7fe8112cc0>],
#   'Action tree': [<action.tree at 0x7f7fe8049780>,
#    <action.tree at 0x7f7fe8049860>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Важные дополнения!\n',
#   'Sentences': [18, 19, 20],
#   'Synt tree': [<action.tree at 0x7f7fe816d748>],
#   'Action tree': [<action.tree at 0x7f7fe8049940>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Все цифры и сроки, что мы рассмотрели, касаются  исключительно иностранного автопрома. Отечественные же марки автомобилей с пробегом более ста тысяч я бы покупать вообще не рекомендовал, конечно, если вы не мастер-самоделкин.\n',
#   'Sentences': [86, 225, 226, 227],
#   'Synt tree': [<action.tree at 0x7f7fe811a550>,
#    <action.tree at 0x7f7fe811da58>],
#   'Action tree': [<action.tree at 0x7f7fe8049a20>,
#    <action.tree at 0x7f7fe8049b70>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'И последнее: выбирая автомобиль с пробегом, всегда обращайте внимание на его предыдущего владельца. Его личность многое может сказать о продаваемом автомобиле.\n',
#   'Sentences': [99, 159, 160, 161],
#   'Synt tree': [<action.tree at 0x7f7fe810e710>,
#    <action.tree at 0x7f7fe80ff320>],
#   'Action tree': [<action.tree at 0x7f7fe8049c88>,
#    <action.tree at 0x7f7fe8049da0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': '© САЙТ\n',
#   'Sentences': [7, 8],
#   'Synt tree': [<action.tree at 0x7f7fe8108550>],
#   'Action tree': [<action.tree at 0x7f7fe8049e80>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Безопасность\n',
#   'Sentences': [13, 14],
#   'Synt tree': [<action.tree at 0x7f7fe8108f28>],
#   'Action tree': [<action.tree at 0x7f7fe8049f28>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Без сомнений, лучше покупать авто хотя бы с минимальным набором средств пассивной безопасности. Таких, например, как SRS, (подушки безопасности): и чем их больше, тем лучше. Очень полезным дополнением к тормозам служит ABS, (антиблокировочная система тормозов). Это устройство помогает эффективнее останавливать автомобиль и при этом избегать заноса, что особенно важно на скользком покрытии.\n',
#   'Sentences': [95, 173, 261, 392, 393, 394],
#   'Synt tree': [<action.tree at 0x7f7fe80b1630>,
#    <action.tree at 0x7f7fe8123cf8>,
#    <action.tree at 0x7f7fe80b49e8>,
#    <action.tree at 0x7f7fe8112ac8>],
#   'Action tree': [<action.tree at 0x7f7fe8049f98>,
#    <action.tree at 0x7f7fe8055048>,
#    <action.tree at 0x7f7fe80550f0>,
#    <action.tree at 0x7f7fe80551d0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Особо привередливые могут сравнить краш-тесты различных марок на сайте журнала «Авто-ревю» или из других источников. Но не стоит забывать, что это всего лишь моделируемые ситуации. Реальные аварии и их последствия могут значительно отличаться от экспериментальных.\n',
#   'Sentences': [116, 180, 264, 265, 266],
#   'Synt tree': [<action.tree at 0x7f7fe811af60>,
#    <action.tree at 0x7f7fe80bbf28>,
#    <action.tree at 0x7f7fe80b4ef0>],
#   'Action tree': [<action.tree at 0x7f7fe80552b0>,
#    <action.tree at 0x7f7fe8055390>,
#    <action.tree at 0x7f7fe80554a8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Также отмечу, что в последнее время каждый автопроизводитель уделяет все больше внимания безопасности водителя и пассажиров. И чем солиднее марка и новее автомобиль, тем больше разнообразных технических новинок из этой области на нем установлено.\n',
#   'Sentences': [124, 246, 247, 248],
#   'Synt tree': [<action.tree at 0x7f7fe812f0b8>,
#    <action.tree at 0x7f7fe80c2da0>],
#   'Action tree': [<action.tree at 0x7f7fe80555f8>,
#    <action.tree at 0x7f7fe8055710>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Размер имеет значение\n',
#   'Sentences': [22, 23],
#   'Synt tree': [<action.tree at 0x7f7fe80c25f8>],
#   'Action tree': [<action.tree at 0x7f7fe80557f0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Большие размеры автомобиля обычно действуют успокаивающе. И не зря. По данным американской статистики, чем массивнее автомобиль, тем он безопаснее. Так что наш «КАМАЗ» вне конкуренции :)\n',
#   'Sentences': [57, 67, 147, 187, 188],
#   'Synt tree': [<action.tree at 0x7f7fe80b1da0>,
#    <action.tree at 0x7f7fe80b1a90>,
#    <action.tree at 0x7f7fe812fba8>,
#    <action.tree at 0x7f7fe80bd208>],
#   'Action tree': [<action.tree at 0x7f7fe80558d0>,
#    <action.tree at 0x7f7fe8055978>,
#    <action.tree at 0x7f7fe80559e8>,
#    <action.tree at 0x7f7fe8055a58>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Влияние цвета на безопасность\n',
#   'Sentences': [30, 31],
#   'Synt tree': [<action.tree at 0x7f7fe80c26d8>],
#   'Action tree': [<action.tree at 0x7f7fe8055ac8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Полезно помнить, что цвет автомобиля будет влиять на вашу безопасность. Согласно новозеландским данным, размещенным в Интернете, автомобили черных, коричневых и зеленых цветов в два раза чаще попадают в ДТП, чем автомобили белые, желтые, серые, красные и синие. И как ни удивительно – самым безопасным признан серебристый цвет. Вероятность попасть в ДТП на таком автомобиле в два раза ниже остальных.\n',
#   'Sentences': [71, 261, 327, 400, 401, 402],
#   'Synt tree': [<action.tree at 0x7f7fe80c6a90>,
#    <action.tree at 0x7f7fe80cfcc0>,
#    <action.tree at 0x7f7fe80dce48>,
#    <action.tree at 0x7f7fe80bbb00>],
#   'Action tree': [<action.tree at 0x7f7fe8055b70>,
#    <action.tree at 0x7f7fe8055cc0>,
#    <action.tree at 0x7f7fe8055e10>,
#    <action.tree at 0x7f7fe8055eb8>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Это происходит потому, что окраска автомобиля существенно влияет на оценку его скорости и расстояния до него. Например, окружающим кажется, что красный автомобиль едет быстрее и находится на более близком расстоянии, чем на самом деле, а для машин синих и зеленых цветов – все наоборот.\n',
#   'Sentences': [109, 286, 287, 288],
#   'Synt tree': [<action.tree at 0x7f7fe80cfa20>,
#    <action.tree at 0x7f7fe80742b0>],
#   'Action tree': [<action.tree at 0x7f7fe8055f98>,
#    <action.tree at 0x7f7fe80600f0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Вывод один: чем заметнее автомобиль для окружающих, тем он и безопаснее.\n',
#   'Sentences': [72, 73, 74],
#   'Synt tree': [<action.tree at 0x7f7fe80ed5f8>],
#   'Action tree': [<action.tree at 0x7f7fe80601d0>]},
#  {'Type': 'paragraph',
#   'Section': None,
#   'Text': 'Не забывайте о том, что включенный при езде свет фар делает ваш автомобиль заметнее, какого бы цвета он ни был.',
#   'Sentences': [111, 112],
#   'Synt tree': [<action.tree at 0x7f7fe8076b38>],
#   'Action tree': [<action.tree at 0x7f7fe8060358>]}]

# %%
from TextProcessing import get_file
get_file(list_, "Выбираем автомобиль.md")

# %% [markdown]
# ## 2. File 'Как выбрать автомобиль.txt'
#
# The original is [Как выбрать автомобиль](https://docs.google.com/document/d/19XVEiCqPcSZif_UmdyLoCjmlHTpl5m-geaw_uBA13F4/edit).

# %%
handle = open("Как выбрать автомобиль.txt", "r")
text = handle.read()
handle.close()
 
list_ = GC(text).get_list()

# %%
show(list_)
# Out:
# Section None
#
#
# Section  Как выбрать автомобиль
#
# Action Action4{принимать}
# Sentence Выбирая железного коня нужно принять во внимание цели его покупки – для работы или досуга , возможности , список пользователей и прочие .
# Action Action2{стоить}
# Sentence Так же стоит задуматься о выборе типа кузова , « начинке » и дополнительной комплектации вашего потенциального авто .
# Action Action9{подходить}
# Sentence Машина вещь дорогостоящая , поэтому к её выбору нужно подойти с особой внимательностью и осторожностью .
# Action Action2{получать}
# Sentence Ниже вы получите несколько советов , которые помогут вам в выборе вашего индивидуального авто .
#
#
# Section Выбор семейного автомобиля
#
# Action Action11{определяться}
# Sentence Если вы выбираете автомобиль для семейных поездок , то вам нужно определиться с размерами авто и типом кузова .
# Action Action4{забывать}
# Sentence Выбирая авто , не забудьте посчитать всех членов своей семьи , также определитесь для каких целей вам семейная машина .
# Action Action0{учитывать}
# Sentence Учтите , что семейный автомобиль нуждается в большем месте для хранения , обычно немного дороже в обслуживании , а его мойка будет стоить гораздо дороже , чем мойка обычного седана .
# Action Action8{следовать}
# Sentence При выборе минивэна или микроавтобуса для семейных поездок следует учитывать комплектацию и наличие дополнительных опций , а что бы путешествие было комфортным обратить внимание на жесткость подвески .
# Action Action22{обращать}
# Sentence При выборе минивэна или микроавтобуса для семейных поездок следует учитывать комплектацию и наличие дополнительных опций , а что бы путешествие было комфортным обратить внимание на жесткость подвески .
# Action Action1{забывать}
# Sentence Не забудьте о кондиционере !
#
#
# Section Сервисы нашего автопортала
#
#
#
# Section Как выбрать автомобиль для новичка
#
#
#
# Section  Как выбрать автомобиль для новичка
#
# Action Action2{давать}
# Sentence Итак , давайте начнем со стажа вождения , если он конечно есть .
# Action Action0{следовать}
# Sentence Следует брать автомобиль без гидро - или электроусилителя руля , это поможет лучше прочувствовать машину , понять радиус поворота или разворота .
# Action Action11{помогать}
# Sentence Следует брать автомобиль без гидро - или электроусилителя руля , это поможет лучше прочувствовать машину , понять радиус поворота или разворота .
# Action Action11{покрасоваться}
# Sentence На старой « копейке » или « девятке » особо не покрасуешься , но опыт , полученный при управлении такой машиной , будет воистину бесценен .
# Action Action1{постыдиться}
# Sentence Не постыдитесь попросить продавца съездить на станцию технического обслуживания , что бы оценить состояние стоек , ходовой и рулевой частей , состояние двигателя , трансмиссии и выхлопной системы .
# Action Action14{покупать}
# Sentence Если механик констатирует состояние автомобиля как удовлетворительное и выше , этот автомобиль можно смело покупать .
# Action Action1{забывать}
# Sentence Не забудьте приобрести наклейку с буквой « У » , так как первые два года после получения прав вы все еще ученик .
#
#
# Section Как выбрать автомобиль для женщины
#
# Action Action0{следовать}
# Sentence Следует выбирать машину с небольшим объемом двигателя , что бы ни возникло желания « рысачить » .
# Action Action13{выбирать}
# Sentence Если стаж вождения значительный или хотя бы больше трех лет , то можно выбрать более мощное авто .
#
#
# Section Как выбрать автомобиль с пробегом
#
# Action Action0{постараться}
# Sentence Постарайтесь выяснить , когда и где была куплена машина , какой у нее по счету хозяин , попадала ли машина в ДТП , какой у нее пробег , как ее хранили .
# Action Action0{избегать}
# Sentence Избегайте также покупки автомобилей , которые работали на такси или были учебными или работали на прокат – обычно эти машины « сливают » , так как их обслуживание слишком дорого .
# Action Action6{следовать}
# Sentence Встретившись или созвонившись с продавцом , следует задать следующие вопросы :
#
# Section list  Год выпуска автомобиля;
#
#
# Section list  Пробег.
#
# Section list  Общее техническое состояние;
#
#
# Section list  Какой ремонт был произведен, когда и почему.
#
# Section list  Количество предыдущих владельцев;
#
#
# Section list  Бывал ли автомобиль в ДТП.
# Action Action5{узнавать}
# Sentence Смело , не стесняясь , узнавайте все подробности о машине .
# Action Action13{доглядывать}
# Sentence Если что - то останется без вашего внимания или где - то не доглядите – это может вылиться в круглую сумму в будущем .
#
#
# Section Какой автомобиль выбрать
#
#
#
# Section  Какой выбрать автомобиль
#
# Action Action4{мочь}
# Sentence На свой борт седан может принять пять человек , имеет вместительный багажник , который разделен с салоном .
#
#
# Section Новый или подержанный автомобиль, какой выбрать
#
#
#
# Section  Новый или подержанный автомобиль, какой выбрать
#
# Action Action9{делать}
# Sentence Следуя логике , новая вещь лучше , но что делать , если ваш бюджет не позволяет купить автомобиль из салона ?
# Action Action7{проходить}
# Sentence Хотя по условиям гарантии новый автомобиль должен проходить техническое обслуживание на фирменной СТО каждые 10 – 15 тысяч километров , что может влететь в копеечку владельцу .
# Action Action5{называть}
# Sentence Из недостатков нового авто можно назвать частый угон и дополнительные траты на систему безопасности .
# Action Action9{собираться}
# Sentence Покупка новой машины выгодна в том случае если вы собираетесь на ней ездить , как минимум пять лет .
# Action Action13{купить}
# Sentence Если у вас есть деньги на новый автомобиль , то за них можно купить подержанный классом гораздо выше или более дорогой марки .
# Action Action14{тратиться}
# Sentence Обычно подержанные автомобили уже оснащены всем необходимым оборудованием и на него не нужно будет тратиться .
# Action Action7{выделять}
# Sentence Из недостатков б / у автомобилей можно выделить внешний вид и общее состояние .
# Action Action2{приходиться}
# Sentence При покупке придется провести диагностику машины , а это влечет за собой дополнительные тельные траты .
# Action Action2{стоить}
# Sentence Так же стоит заметить , что подержанный автомобиль будет иметь следы эксплуатации предыдущими хозяевами , что может быть неприятно , особенно брезгливым автолюбителям .
# Action Action7{предстоять}
# Sentence Приняв во внимание все вышеперечисленное , вам предстоит самостоятельно сделать выбор в пользу нового или подержанного автомобиля .
#
#
# Section Какой цвет автомобиля выбрать
#
# Action Action6{выбирать}
# Sentence Казалось бы , ответ прост – выбирай любимый , но в современных условиях производители предлагают такое количество цветов и оттенков , что ваш вкус может измениться .
# Action Action4{учитывать}
# Sentence Выбирая цвет автомобиля , учтите фактор видимости его на дороге .
# Action Action0{иметь}
# Sentence Имейте это ввиду и на тот случай , если нужна будет покраска в будущем .
#
#
# Section Как купить автомобиль в кредит
#
# Action Action0{следовать}
# Sentence Следует собрать пакет документов .
#
#
# Section Как застраховать автомобиль
#
# Action Action6{обращаться}
# Sentence Что бы застраховать автомобиль , необходимо обратиться в страховую компанию .
# Action Action0{выбирать}
# Sentence Выбрать страховщика можно по нескольким критериям : авторитет и история компании , история выплат , рекомендации людей , застраховавших свои авто или уже получавших выплаты .
# Action Action2{застраховывать}
# Sentence Автомобиль можно застраховать от угона , уничтожения , любого другого повреждения .

# %%
get_file(list_, "Как выбрать автомобиль.md")
